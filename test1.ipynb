# %%
# the below code will get data from your google drive

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

# %%
# change training data .csv to ANY FILE U WANT NEXT TIME

# %%
page_token = None
while True:
    response = drive_service.files().list(q="name='training_data.csv'",
                                          spaces='drive',
                                          fields='nextPageToken, files(id, name)',
                                          pageToken=page_token).execute()
    for file in response.get('files', []):
        # Process change
        print (file.get('name'), file.get('id'))
    page_token = response.get('nextPageToken', None)
    if page_token is None:
        break
# Out:
# training_data.csv 1DHOucAvwfMjStI49Nxx7D_9Oeoa9H5Mx

# %%
#
# Replace the assignment below with your file ID
# to download a different file.
#
# A file ID looks like: 1uBtlaggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '1DHOucAvwfMjStI49Nxx7D_9Oeoa9H5Mx'

import io
from googleapiclient.http import MediaIoBaseDownload

request = drive_service.files().get_media(fileId=file_id)
downloaded = io.BytesIO()
downloader = MediaIoBaseDownload(downloaded, request)
done = False
while done is False:
  # _ is a placeholder for a progress object that we ignore.
  # (Our file is small, so we skip reporting progress.)
  _, done = downloader.next_chunk()

downloaded.seek(0)
# Out:
# 0

# %%
import pandas as pd;

# %%
##Imported training_data

# %%
df=pd.read_csv(downloaded)

# %%
page_token = None
while True:
    response = drive_service.files().list(q="name='test_data .csv'",
                                          spaces='drive',
                                          fields='nextPageToken, files(id, name)',
                                          pageToken=page_token).execute()
    for file in response.get('files', []):
        # Process change
        print (file.get('name'), file.get('id'))
    page_token = response.get('nextPageToken', None)
    if page_token is None:
        break
# Out:
# test_data .csv 1IJYMmh4pYm1_9FLr8Y2GWGHr-pdvt3qB

# %%
file_id = '1IJYMmh4pYm1_9FLr8Y2GWGHr-pdvt3qB'

import io
from googleapiclient.http import MediaIoBaseDownload

request = drive_service.files().get_media(fileId=file_id)
downloaded1 = io.BytesIO()
downloader = MediaIoBaseDownload(downloaded1, request)
done = False
while done is False:
  # _ is a placeholder for a progress object that we ignore.
  # (Our file is small, so we skip reporting progress.)
  _, done = downloader.next_chunk()

downloaded1.seek(0)
# Out:
# 0

# %%
##Imported test_data

# %%
test=pd.read_csv(downloaded1)

# %%
import numpy as np;

# %%
import numpy as np;

finaldf=df;

# %%
###Extracting features

# %%
##Feature 1: Clickcount

# %%
tr=df.groupby(['id']).count()
temp=tr['timestamp'].to_frame()
temp.reset_index(level=0,inplace=True)
temp.columns=['id','Clickcount']
finaldf=pd.merge(df,temp,on='id')

# %%
finaldf.sort_values('id').head()
# Out:
#              id              ad               link  \
# 69893  session0             NaN  link1288490188815
# 69901  session0             NaN  link1357209665544
# 69900  session0             NaN  link1125281431562
# 69899  session0  ad481036337152   link274877906965
# 69898  session0  ad481036337152   link781684047909
#
#                            timestamp  checkout  order_placed  \
# 69893  2018-04-30T02:01:59.000-04:00         0             0
# 69901  2018-04-30T02:00:56.000-04:00         0             0
# 69900  2018-04-30T02:01:52.000-04:00         0             0
# 69899  2018-04-30T10:46:58.000-04:00         0             0
# 69898  2018-04-30T02:10:22.000-04:00         0             0
#
#                     grp funnel_level  Clickcount
# 69893  grp1340029796352        upper          11
# 69901   grp936302870528        upper          11
# 69900   grp936302870528        upper          11
# 69899  grp1297080123392       middle          11
# ...

# %%
##Feature 2: No of unique links clicked

# %%
tr=df;

temp=tr.groupby('id')['link'].nunique()
temp=temp.to_frame()
temp.reset_index(level=0,inplace=True)
temp.columns=['id','uniqueLinks']
finaldf=pd.merge(finaldf,temp,on='id')
finaldf.head(2)
# Out:
#                     id              ad               link  \
# 0  session446676598812  ad412316860435  link1288490188810
# 1  session446676598812             NaN  link1288490188816
#
#                        timestamp  checkout  order_placed               grp  \
# 0  2018-04-30T14:39:22.000-04:00         1             1   grp936302870529
# 1  2018-04-30T14:15:09.000-04:00         1             1  grp1340029796352
#
#   funnel_level  Clickcount  uniqueLinks
# 0        lower         140           63
# 1        upper         140           63

# %%
##Feature 3: Check funnel is low in each session

# %%
tr=df;
temp=tr[tr['funnel_level']=='lower'];
temp['id'];
z=tr[~tr.id.isin(temp['id'])];
y=df;
finaldf['haslower']=y['id'].isin(temp['id']);
finaldf.head()
# Out:
#                     id              ad               link  \
# 0  session446676598812  ad412316860435  link1288490188810
# 1  session446676598812             NaN  link1288490188816
# 2  session446676598812  ad412316860435  link1288490188816
# 3  session446676598812  ad412316860435  link1288490188816
# 4  session446676598812  ad412316860435  link1288490188816
#
#                        timestamp  checkout  order_placed               grp  \
# 0  2018-04-30T14:39:22.000-04:00         1             1   grp936302870529
# 1  2018-04-30T14:15:09.000-04:00         1             1  grp1340029796352
# 2  2018-04-30T14:45:17.000-04:00         1             1  grp1340029796352
# 3  2018-04-30T14:46:40.000-04:00         1             1  grp1340029796352
# 4  2018-04-30T14:54:54.000-04:00         1             1  grp1340029796352
#
#   funnel_level  Clickcount  uniqueLinks  haslower
# 0        lower         140           63      True
# 1        upper         140           63      True
# ...

# %%
##Featue 4:Getting avg time between clicks of session and Featue 5: Total session time

# %%
tr=df;
tr=tr.sort_values(['id','timestamp']);
tr.head();
tr['timestamp']=pd.to_datetime(tr['timestamp']);
tr['timediffbetclicks']=tr.groupby('id')['timestamp'].diff();
tr['timediffbetclicks']=tr['timediffbetclicks'].fillna(0);

# %%
tr['timeSecondsbetweenclicks']=[(x.total_seconds()) for x in tr['timediffbetclicks']];

# %%
temp=tr.groupby('id')['timeSecondsbetweenclicks'].mean().to_frame();

# %%
temp.reset_index(level=0,inplace=True);

# %%
temp.columns=['id','avgTimebetweenClicks'];
temp1 = (tr.groupby('id')['timestamp'].last() -tr.groupby('id')['timestamp'].first()).to_frame();
temp1.reset_index(level=0,inplace=True)

# %%
temp1.columns=['id','totalSessionTime'];

# %%
#Convert time difference to seconds
time=pd.DatetimeIndex(temp1['totalSessionTime'])
temp1['totalSessionTime'] = [(x.total_seconds()) for x in temp1['totalSessionTime']]
temp1.head()
# Out:
#                      id  totalSessionTime
# 0              session0           31562.0
# 1             session10               0.0
# 2  session1005022347264             175.0
# 3  session1005022347265             102.0
# 4  session1005022347267            2381.0

# %%
temp2=pd.merge(temp,temp1,on='id');
finaldf=pd.merge(finaldf,temp2,on='id');
finaldf.head(2)
# Out:
#                     id              ad               link  \
# 0  session446676598812  ad412316860435  link1288490188810
# 1  session446676598812             NaN  link1288490188816
#
#                        timestamp  checkout  order_placed               grp  \
# 0  2018-04-30T14:39:22.000-04:00         1             1   grp936302870529
# 1  2018-04-30T14:15:09.000-04:00         1             1  grp1340029796352
#
#   funnel_level  Clickcount  uniqueLinks  haslower  avgTimebetweenClicks  \
# 0        lower         140           63      True             85.014286
# 1        upper         140           63      True             85.014286
#
#    totalSessionTime
# 0           11902.0
# 1           11902.0

# %%
##Feature 6: Getting hour of session

# %%
tr=df;
tr=tr.sort_values(['id','timestamp']);
tr['timestamp']=pd.to_datetime(tr['timestamp']);
tr['hour']=tr['timestamp'].dt.hour;

# %%
temp = tr.loc[:,['id','hour']];

# %%
finaldf=pd.merge(finaldf,temp,on='id');
finaldf.head()
# Out:
#                     id              ad               link  \
# 0  session446676598812  ad412316860435  link1288490188810
# 1  session446676598812  ad412316860435  link1288490188810
# 2  session446676598812  ad412316860435  link1288490188810
# 3  session446676598812  ad412316860435  link1288490188810
# 4  session446676598812  ad412316860435  link1288490188810
#
#                        timestamp  checkout  order_placed              grp  \
# 0  2018-04-30T14:39:22.000-04:00         1             1  grp936302870529
# 1  2018-04-30T14:39:22.000-04:00         1             1  grp936302870529
# 2  2018-04-30T14:39:22.000-04:00         1             1  grp936302870529
# 3  2018-04-30T14:39:22.000-04:00         1             1  grp936302870529
# 4  2018-04-30T14:39:22.000-04:00         1             1  grp936302870529
#
#   funnel_level  Clickcount  uniqueLinks  haslower  avgTimebetweenClicks  \
# 0        lower         140           63      True             85.014286
# ...

# %%
## Feature 7: Unique groups

# %%
tr=df;
temp=tr.groupby('id')['grp'].nunique().to_frame();
temp.reset_index(level=0,inplace=True);
temp.columns=['id','Uniquegroups'];
finaldf=pd.merge(finaldf,temp,on='id');

# %%
final=finaldf.drop_duplicates(['id'],keep="first")

# %%
final.head()
# Out:
#                          id               ad               link  \
# 0       session446676598812   ad412316860435  link1288490188810
# 19600    session60129542152   ad584115552306  link1288490188810
# 20624  session1511828488251  ad1056561954841  link1288490188810
# 23328  session1142461300754  ad1666447310876  link1288490188810
# 25828  session1314259992659             ad34  link1288490188800
#
#                            timestamp  checkout  order_placed              grp  \
# 0      2018-04-30T14:39:22.000-04:00         1             1  grp936302870529
# 19600  2018-04-30T08:39:23.000-04:00         1             1  grp936302870529
# 20624  2018-04-30T17:24:01.000-04:00         1             1  grp936302870529
# 23328  2018-04-30T10:42:57.000-04:00         1             1  grp936302870529
# 25828  2018-04-30T22:58:04.000-04:00         1             1  grp111669149696
#
#       funnel_level  Clickcount  uniqueLinks  haslower  avgTimebetweenClicks  \
# ...

# %%
tr=df;
tr=tr.sort_values(['id','timestamp']);
tr['timestamp']=pd.to_datetime(tr['timestamp']);
tr['timebetclicks']=tr.groupby('id')['timestamp'].diff();
tr['timebetclicks']=tr['timebetclicks'].fillna(0);
tr['timeinsecs']=[(x.total_seconds()) for x in tr['timebetclicks']];

# %%
##Feature 8: Total time in upper
temp=tr[tr['funnel_level']=='upper'];
temp1 = temp.groupby('id')['timeinsecs'].sum().to_frame();
temp1.reset_index(level=0,inplace=True);
temp1.columns=['id','timeinupper'];

# %%
##Feature 9: Total time in middle
temp=tr[tr['funnel_level']=='middle'];
temp2 = temp.groupby('id')['timeinsecs'].sum().to_frame();
temp2.reset_index(level=0,inplace=True);
temp2.columns=['id','timeinmiddle'];

# %%
##Feature 10: Total time in lower
temp=tr[tr['funnel_level']=='lower'];
temp3 = temp.groupby('id')['timeinsecs'].sum().to_frame();
temp3.reset_index(level=0,inplace=True);
temp3.columns=['id','timeinlower'];

# %%
final_train = pd.merge(final,temp1,on='id',how='left')

# %%
final_train = pd.merge(final_train,temp2,on='id',how='left')

# %%
final_train = pd.merge(final_train,temp3,on='id',how='left')

# %%
final_train.head()
# Out:
#                      id               ad               link  \
# 0   session446676598812   ad412316860435  link1288490188810
# 1    session60129542152   ad584115552306  link1288490188810
# 2  session1511828488251  ad1056561954841  link1288490188810
# 3  session1142461300754  ad1666447310876  link1288490188810
# 4  session1314259992659             ad34  link1288490188800
#
#                        timestamp  checkout  order_placed              grp  \
# 0  2018-04-30T14:39:22.000-04:00         1             1  grp936302870529
# 1  2018-04-30T08:39:23.000-04:00         1             1  grp936302870529
# 2  2018-04-30T17:24:01.000-04:00         1             1  grp936302870529
# 3  2018-04-30T10:42:57.000-04:00         1             1  grp936302870529
# 4  2018-04-30T22:58:04.000-04:00         1             1  grp111669149696
#
#   funnel_level  Clickcount  uniqueLinks  haslower  avgTimebetweenClicks  \
# 0        lower         140           63      True             85.014286
# ...

# %%
## Dropping unwanted variables

# %%
final_train.drop(['ad','link','timestamp','checkout','grp','funnel_level'],axis=1,inplace=True);
final_train = final_train.set_index('id');

# %%
final_train.head()
# Out:
#                       order_placed  Clickcount  uniqueLinks  haslower  \
# id
# session446676598812              1         140           63      True
# session60129542152               1          32           30      True
# session1511828488251             1          52           40      True
# session1142461300754             1          50           34      True
# session1314259992659             1          78           57      True
#
#                       avgTimebetweenClicks  totalSessionTime  hour  \
# id
# session446676598812              85.014286           11902.0    16
# session60129542152              816.718750           26135.0    12
# session1511828488251             25.269231            1314.0    21
# session1142461300754             26.160000            1308.0    14
# session1314259992659             54.910256            4283.0     2
#
#                       Uniquegroups  timeinupper  timeinmiddle  timeinlower
# id
# ...

# %%
columns=final_train.columns

# %%
final_train=final_train.fillna(0)

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

# %%
np_scaled = min_max_scaler.fit_transform(final_train)

# %%
columns
# Out:
# Index(['order_placed', 'Clickcount', 'uniqueLinks', 'haslower',
#        'avgTimebetweenClicks', 'totalSessionTime', 'hour', 'Uniquegroups',
#        'timeinupper', 'timeinmiddle', 'timeinlower'],
#       dtype='object')

# %%
##Normalising the data

# %%
final_normalized = pd.DataFrame(np_scaled);
final_normalized.columns=[columns]
final_normalized.head()
# Out:
#   order_placed Clickcount uniqueLinks haslower avgTimebetweenClicks  \
# 0          1.0   0.594017    0.681319      1.0             0.003579
# 1          1.0   0.132479    0.318681      1.0             0.034385
# 2          1.0   0.217949    0.428571      1.0             0.001064
# 3          1.0   0.209402    0.362637      1.0             0.001101
# 4          1.0   0.329060    0.615385      1.0             0.002312
#
#   totalSessionTime      hour Uniquegroups timeinupper timeinmiddle timeinlower
# 0         0.141517  0.695652     0.764706    0.106068     0.019711    0.026782
# 1         0.310750  0.521739     0.617647    0.312296     0.002469    0.007372
# 2         0.015624  0.913043     0.647059    0.003016     0.003937    0.011975
# 3         0.015552  0.608696     0.676471    0.000956     0.005355    0.012766
# 4         0.050926  0.086957     0.794118    0.000797     0.031080    0.027889

# %%
X= final_normalized.iloc[:,1:]

# %%
y=final_normalized['order_placed']

# %%
## Spliting the training_data into train and test data to build and evaluate model

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

# %%
##Distributed random forest
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}
# Create a based model
rf = RandomForestRegressor()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
# Fit the grid search to the data
gr=grid_search.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 288 candidates, totalling 864 fits
# [CV] bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV] bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV]  bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100, total=   0.7s
# ...

# %%
gr.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 110,
#  'max_features': 3,
#  'min_samples_leaf': 5,
#  'min_samples_split': 10,
#  'n_estimators': 300}

# %%
#RandomForestClassifier(random_state=43) 
clf_rf = RandomForestClassifier(criterion='gini', n_estimators=200,
                             min_samples_split=5,min_samples_leaf=3,
                             oob_score=True,
                             random_state=42,n_jobs=-1)

# %%
clr_rf = clf_rf.fit(x_train,y_train)
ac = accuracy_score(y_test,clf_rf.predict(x_test))
ac
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# 0.970745629682483

# %%
import seaborn as sns # data visualization library  
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(y_test,clf_rf.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")
plt.show()

# %%
y_pred=clf_rf.predict(x_test)

# %%
#Accuracy

# %%
from sklearn import metrics
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import pylab as pl
print("Accuracy", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy 0.9725294327506243

# %%
#AUC

# %%
y_pred_proba = clf_rf.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
# calculate the fpr and tpr for all thresholds of the classification
probs = clf_rf.predict_proba(x_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# Compute Precision-Recall and plot curve
precision, recall, thresholds = precision_recall_curve(y_test, preds)
area = auc(recall, precision)
print (area)

pl.clf()
pl.plot(recall, precision, label='Precision-Recall curve')
pl.xlabel('Recall')
pl.ylabel('Precision')
pl.ylim([0.0, 1.05])
pl.xlim([0.0, 1.0])
pl.title('Precision-Recall example: AUC=%0.2f' % area)
pl.legend(loc="lower left")
pl.show()
# Out:
# 0.8271471108794273

# %%
gb=GradientBoostingClassifier(loss='deviance', learning_rate=0.1, n_estimators=200, subsample=1.0, 
                              criterion='friedman_mse', min_samples_split=5, min_samples_leaf=3,
                              min_weight_fraction_leaf=0.0, max_depth=5, min_impurity_decrease=0.0,
                              min_impurity_split=None, init=None, random_state=None, max_features=None, 
                              verbose=0, max_leaf_nodes=None, 
                              warm_start=False, presort='auto')

gb = gb.fit(x_train,y_train)
ac = accuracy_score(y_test,gb.predict(x_test))
ac
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9653942204780592

# %%
cm = confusion_matrix(y_test,gb.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")
plt.show()

# %%
y_pred1=gb.predict(x_test)
print("Accuracy", metrics.accuracy_score(y_test, y_pred1))
# Out:
# Accuracy 0.9653942204780592

# %%
# calculate the fpr and tpr for all thresholds of the classification
probs = gb.predict_proba(x_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# Compute Precision-Recall and plot curve
precision, recall, thresholds = precision_recall_curve(y_test, preds)
area = auc(recall, precision)
print (area)

pl.clf()
pl.plot(recall, precision, label='Precision-Recall curve')
pl.xlabel('Recall')
pl.ylabel('Precision')
pl.ylim([0.0, 1.05])
pl.xlim([0.0, 1.0])
pl.title('Precision-Recall example: AUC=%0.2f' % area)
pl.legend(loc="lower left")
pl.show()
# Out:
# 0.7632716118323355

# %%
##Extracting features from test_data

# %%
test.head()
# Out:
#                      id               ad               link  \
# 0   session240518168612   ad678604832787  link1288490188810
# 1   session876173328405  ad1451698946059  link1288490188810
# 2  session1382979469382  ad1468878815242  link1288490188810
# 3   session927712936010             ad64  link1288490188800
# 4   session970662608923    ad17179869199  link1288490188800
#
#                        timestamp              grp funnel_level
# 0  2018-04-30T16:55:51.000-04:00  grp936302870529        lower
# 1  2018-04-30T12:36:40.000-04:00  grp936302870529        lower
# 2  2018-04-30T20:20:44.000-04:00  grp936302870529        lower
# 3  2018-04-30T21:32:33.000-04:00  grp111669149696        lower
# 4  2018-04-30T15:49:45.000-04:00  grp111669149696        lower

# %%
final_test=test;
tr=test.groupby(['id']).count()
temp=tr['timestamp'].to_frame()
temp.reset_index(level=0,inplace=True)
temp.columns=['id','Clickcount']
final_test=pd.merge(final_test,temp,on='id')

final_test.sort_values('id').head()
# Out:
#              id               ad               link  \
# 16772  session1  ad1640677507072  link1511828488195
# 16774  session1              NaN  link1125281431562
# 16771  session1              NaN   link824633720850
# 16770  session1              NaN   link755914244118
# 16769  session1              NaN   link755914244118
#
#                            timestamp               grp funnel_level  \
# 16772  2018-04-30T04:10:37.000-04:00   grp257698037760       middle
# 16774  2018-04-30T04:09:03.000-04:00   grp936302870528        upper
# 16771  2018-04-30T04:09:13.000-04:00  grp1340029796352        upper
# 16770  2018-04-30T04:09:25.000-04:00  grp1340029796352        upper
# 16769  2018-04-30T04:09:24.000-04:00  grp1340029796352        upper
#
#        Clickcount
# 16772          10
# 16774          10
# 16771          10
# 16770          10
# 16769          10

# %%
# No of unique links clicks in test data
tr=test;
temp=tr.groupby('id')['link'].nunique()
temp=temp.to_frame()
temp.reset_index(level=0,inplace=True)
temp.columns=['id','uniqueLinks']

temp.head()
# Out:
#                      id  uniqueLinks
# 0              session1            9
# 1  session1005022347266           10
# 2  session1005022347272           11
# 3  session1005022347276           22
# 4  session1005022347280           15

# %%
final_test=pd.merge(final_test,temp,on='id')
final_test.head(2)
# Out:
#                     id              ad               link  \
# 0  session240518168612  ad678604832787  link1288490188810
# 1  session240518168612             NaN  link1288490188815
#
#                        timestamp               grp funnel_level  Clickcount  \
# 0  2018-04-30T16:55:51.000-04:00   grp936302870529        lower          57
# 1  2018-04-30T12:33:22.000-04:00  grp1340029796352        upper          57
#
#    uniqueLinks
# 0           39
# 1           39

# %%
#Check funnel is not low but order is 1
tr=test;
temp=tr[tr['funnel_level']=='lower'];
temp['id'];
z=tr[~tr.id.isin(temp['id'])];


y=test;
final_test['haslower']=y['id'].isin(temp['id']);
final_test.head()
# Out:
#                     id              ad               link  \
# 0  session240518168612  ad678604832787  link1288490188810
# 1  session240518168612             NaN  link1288490188815
# 2  session240518168612             NaN   link798863917076
# 3  session240518168612             NaN   link532575944722
# 4  session240518168612  ad678604832787   link369367187473
#
#                        timestamp               grp funnel_level  Clickcount  \
# 0  2018-04-30T16:55:51.000-04:00   grp936302870529        lower          57
# 1  2018-04-30T12:33:22.000-04:00  grp1340029796352        upper          57
# 2  2018-04-30T12:33:29.000-04:00  grp1340029796352        upper          57
# 3  2018-04-30T12:33:30.000-04:00  grp1340029796352        upper          57
# 4  2018-04-30T16:50:20.000-04:00  grp1357209665536        lower          57
#
#    uniqueLinks  haslower
# 0           39      True
# 1           39      True
# 2           39      True
# 3           39      True
# 4           39      True

# %%
#Getting avg time of session
tr=test;
tr=tr.sort_values(['id','timestamp']);
tr.head();
tr['timestamp']=pd.to_datetime(tr['timestamp']);
tr['timediffbetclicks']=tr.groupby('id')['timestamp'].diff();
tr['timediffbetclicks']=tr['timediffbetclicks'].fillna(0);
tr.head()
tr['timeSecondsbetweenclicks']=[(x.total_seconds()) for x in tr['timediffbetclicks']];
tr.head()
temp=tr.groupby('id')['timeSecondsbetweenclicks'].mean().to_frame();
temp.head()
temp.reset_index(level=0,inplace=True);
temp.head()
temp.columns=['id','avgTimebeforeClicks'];
temp1 = (tr.groupby('id')['timestamp'].last() -tr.groupby('id')['timestamp'].first()).to_frame();
temp1.reset_index(level=0,inplace=True)
temp1.head()
temp1.columns=['id','totalSessionTime'];
#Convert time difference to seconds
time=pd.DatetimeIndex(temp1['totalSessionTime'])
temp1['totalSessionTime'] = [(x.total_seconds()) for x in temp1['totalSessionTime']]
temp1.head()
temp2=pd.merge(temp,temp1,on='id');
final_test=pd.merge(final_test,temp2,on='id');
final_test.head(2)
tr=test;
tr=tr.sort_values(['id','timestamp']);
tr['timestamp']=pd.to_datetime(tr['timestamp']);
tr['hour']=tr['timestamp'].dt.hour;
tr.head()
temp = tr.loc[:,['id','hour']];
temp.head(1)
final_test=pd.merge(final_test,temp,on='id');
final_test.head()
# Out:
#                     id              ad               link  \
# 0  session240518168612  ad678604832787  link1288490188810
# 1  session240518168612  ad678604832787  link1288490188810
# 2  session240518168612  ad678604832787  link1288490188810
# 3  session240518168612  ad678604832787  link1288490188810
# 4  session240518168612  ad678604832787  link1288490188810
#
#                        timestamp              grp funnel_level  Clickcount  \
# 0  2018-04-30T16:55:51.000-04:00  grp936302870529        lower          57
# 1  2018-04-30T16:55:51.000-04:00  grp936302870529        lower          57
# 2  2018-04-30T16:55:51.000-04:00  grp936302870529        lower          57
# 3  2018-04-30T16:55:51.000-04:00  grp936302870529        lower          57
# 4  2018-04-30T16:55:51.000-04:00  grp936302870529        lower          57
#
#    uniqueLinks  haslower  avgTimebeforeClicks  totalSessionTime  hour
# 0           39      True           288.140351           16424.0    16
# ...

# %%
#Unique groups
tr=test;
temp=tr.groupby('id')['grp'].nunique().to_frame();
temp.reset_index(level=0,inplace=True);
temp.columns=['id','Uniquegroups'];
final_test=pd.merge(final_test,temp,on='id');
final_test.head()

final_test=final_test.drop_duplicates(['id'],keep="first")
final_test.head()
# Out:
#                          id               ad               link  \
# 0       session240518168612   ad678604832787  link1288490188810
# 3249    session876173328405  ad1451698946059  link1288490188810
# 10645  session1382979469382  ad1468878815242  link1288490188810
# 11045   session927712936010             ad64  link1288490188800
# 11829   session970662608923    ad17179869199  link1288490188800
#
#                            timestamp              grp funnel_level  \
# 0      2018-04-30T16:55:51.000-04:00  grp936302870529        lower
# 3249   2018-04-30T12:36:40.000-04:00  grp936302870529        lower
# 10645  2018-04-30T20:20:44.000-04:00  grp936302870529        lower
# 11045  2018-04-30T21:32:33.000-04:00  grp111669149696        lower
# 11829  2018-04-30T15:49:45.000-04:00  grp111669149696        lower
#
#        Clickcount  uniqueLinks  haslower  avgTimebeforeClicks  \
# 0              57           39      True           288.140351
# ...

# %%
tr=test;
tr=tr.sort_values(['id','timestamp']);
tr['timestamp']=pd.to_datetime(tr['timestamp']);
tr['timebetclicks']=tr.groupby('id')['timestamp'].diff();
tr['timebetclicks']=tr['timebetclicks'].fillna(0);
tr['timeinsecs']=[(x.total_seconds()) for x in tr['timebetclicks']];
tr.head(20)
# Out:
#                          id               ad               link  \
# 33074              session1              NaN  link1125281431562
# 817                session1              NaN  link1288490188815
# 21662              session1              NaN   link824633720850
# 12604              session1              NaN   link755914244118
# 12605              session1              NaN   link755914244118
# 3944               session1              NaN   link798863917076
# 7648               session1              NaN   link532575944722
# 10403              session1              NaN   link214748364811
# 22565              session1  ad1640677507072  link1511828488195
# 26890              session1  ad1640677507072   link970662608920
# 38744  session1005022347266              NaN  link1503238553612
# 30432  session1005022347266              NaN  link1649267441683
# 27396  session1005022347266              NaN  link1408749273114
# 2275   session1005022347266              NaN  link1288490188815
# ...

# %%
##Total time in upper
temp=tr[tr['funnel_level']=='upper'];
temp1 = temp.groupby('id')['timeinsecs'].sum().to_frame();
temp1.reset_index(level=0,inplace=True);
temp1.columns=['id','timeinupper'];
temp1.head()
# Out:
#                      id  timeinupper
# 0              session1         36.0
# 1  session1005022347266        327.0
# 2  session1005022347272       1984.0
# 3  session1005022347276        875.0
# 4  session1005022347280         47.0

# %%
#timeinmiddle
temp=tr[tr['funnel_level']=='middle'];
temp2 = temp.groupby('id')['timeinsecs'].sum().to_frame();
temp2.reset_index(level=0,inplace=True);
temp2.columns=['id','timeinmiddle'];
temp2.head()

#timeinlower
temp=tr[tr['funnel_level']=='lower'];
temp3 = temp.groupby('id')['timeinsecs'].sum().to_frame();
temp3.reset_index(level=0,inplace=True);
temp3.columns=['id','timeinlower'];
temp3.head()
# Out:
#                      id  timeinlower
# 0  session1005022347276      10406.0
# 1  session1005022347280        290.0
# 2  session1005022347298         35.0
# 3  session1005022347323        451.0
# 4  session1013612281857        359.0

# %%
# tryoing left merge with final 
 
final_test1 = pd.merge(final_test,temp1,on='id',how='left')

final_test1 = pd.merge(final_test1,temp2,on='id',how='left')

final_test1 = pd.merge(final_test1,temp3,on='id',how='left')
final_test1.head()
# Out:
#                      id               ad               link  \
# 0   session240518168612   ad678604832787  link1288490188810
# 1   session876173328405  ad1451698946059  link1288490188810
# 2  session1382979469382  ad1468878815242  link1288490188810
# 3   session927712936010             ad64  link1288490188800
# 4   session970662608923    ad17179869199  link1288490188800
#
#                        timestamp              grp funnel_level  Clickcount  \
# 0  2018-04-30T16:55:51.000-04:00  grp936302870529        lower          57
# 1  2018-04-30T12:36:40.000-04:00  grp936302870529        lower          86
# 2  2018-04-30T20:20:44.000-04:00  grp936302870529        lower          20
# 3  2018-04-30T21:32:33.000-04:00  grp111669149696        lower          28
# 4  2018-04-30T15:49:45.000-04:00  grp111669149696        lower          56
#
#    uniqueLinks  haslower  avgTimebeforeClicks  totalSessionTime  hour  \
# 0           39      True           288.140351           16424.0    16
# ...

# %%
final_test1.head()
# Out:
#                      id               ad               link  \
# 0   session240518168612   ad678604832787  link1288490188810
# 1   session876173328405  ad1451698946059  link1288490188810
# 2  session1382979469382  ad1468878815242  link1288490188810
# 3   session927712936010             ad64  link1288490188800
# 4   session970662608923    ad17179869199  link1288490188800
#
#                        timestamp              grp funnel_level  Clickcount  \
# 0  2018-04-30T16:55:51.000-04:00  grp936302870529        lower          57
# 1  2018-04-30T12:36:40.000-04:00  grp936302870529        lower          86
# 2  2018-04-30T20:20:44.000-04:00  grp936302870529        lower          20
# 3  2018-04-30T21:32:33.000-04:00  grp111669149696        lower          28
# 4  2018-04-30T15:49:45.000-04:00  grp111669149696        lower          56
#
#    uniqueLinks  haslower  avgTimebeforeClicks  totalSessionTime  hour  \
# 0           39      True           288.140351           16424.0    16
# ...

# %%
final_test1.drop(['ad','link','timestamp','grp','funnel_level'],axis=1,inplace=True);
final_test1 = final_test1.set_index('id')

# %%
final_test1=final_test1.fillna(0);

# %%
final_test1.head()
# Out:
#                       Clickcount  uniqueLinks  haslower  avgTimebeforeClicks  \
# id
# session240518168612           57           39      True           288.140351
# session876173328405           86           60      True            54.604651
# session1382979469382          20           18      True           365.500000
# session927712936010           28           20      True            19.142857
# session970662608923           56           43      True           184.660714
#
#                       totalSessionTime  hour  Uniquegroups  timeinupper  \
# id
# session240518168612            16424.0    16            22      15135.0
# session876173328405             4696.0    15            29       1155.0
# session1382979469382            7310.0     0             9       6590.0
# session927712936010              536.0     1            14         33.0
# session970662608923            10341.0    16            24        121.0
#
#                       timeinmiddle  timeinlower
# id
# ...

# %%
columns=final_test1.columns

# %%
np_scaled_test = min_max_scaler.fit_transform(final_test1)

# %%
final_normalized_test = pd.DataFrame(np_scaled_test);

# %%
final_normalized_test.columns=[columns]

# %%
final_normalized_test.head()
# Out:
#   Clickcount uniqueLinks haslower avgTimebeforeClicks totalSessionTime  \
# 0   0.290155    0.436782      1.0            0.012886         0.215084
# 1   0.440415    0.678161      1.0            0.002442         0.061497
# 2   0.098446    0.195402      1.0            0.016346         0.095729
# 3   0.139896    0.218391      1.0            0.000856         0.007019
# 4   0.284974    0.482759      1.0            0.008259         0.135423
#
#        hour Uniquegroups timeinupper timeinmiddle timeinlower
# 0  0.695652      0.65625    0.244267     0.012223    0.038221
# 1  0.652174      0.87500    0.018641     0.055308    0.058158
# 2  0.000000      0.25000    0.106357     0.001859    0.032059
# 3  0.043478      0.40625    0.000533     0.001534    0.021890
# 4  0.695652      0.71875    0.001953     0.232943    0.009818

# %%
####Final prediction
pred=clf_rf.predict(final_normalized_test)
print(pred)
# Out:
# [1. 1. 0. ... 0. 0. 0.]

# %%
final_test1['order_placed']=pred
final_test1.head()
# Out:
#    index                    id  Clickcount  uniqueLinks  haslower  \
# 0      0   session240518168612          57           39      True
# 1      1   session876173328405          86           60      True
# 2      2  session1382979469382          20           18      True
# 3      3   session927712936010          28           20      True
# 4      4   session970662608923          56           43      True
#
#    avgTimebeforeClicks  totalSessionTime  hour  Uniquegroups  timeinupper  \
# 0           288.140351           16424.0    16            22      15135.0
# 1            54.604651            4696.0    15            29       1155.0
# 2           365.500000            7310.0     0             9       6590.0
# 3            19.142857             536.0     1            14         33.0
# 4           184.660714           10341.0    16            24        121.0
#
#    timeinmiddle  timeinlower  order_placed
# 0         526.0        763.0           1.0
# ...

# %%
final_test1.reset_index(level=0,inplace=True)
final_pred = final_test1[['id','order_placed']]

# %%
final_pred['order_placed']=final_pred['order_placed'].astype(int)

final_pred.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                      id  order_placed
# 0   session240518168612             1
# 1   session876173328405             1
# 2  session1382979469382             0
# 3   session927712936010             1
# 4   session970662608923             1

# %%
final_pred.to_csv('Submission.csv',index=False)

# %%
from google.colab import files
files.download('Submission.csv')

# %%
sns.distplot(final['Clickcount'])

# %%
sns.distplot(final['hour'])

# %%
tr=df
orderlinks=np.unique(tr[ (tr['order_placed']==1)]['link'])
noorderlinks=np.unique(tr[ (tr['order_placed']==0)]['link'])
len(np.setdiff1d(orderlinks,noorderlinks))
# Out:
# 542

# %%
len(np.setdiff1d(noorderlinks,orderlinks))
# Out:
# 2767

# %%
clf_rf.feature_importances_
# Out:
# array([0.05583082, 0.08070301, 0.0045632 , 0.03685718, 0.04811982,
#        0.02156492, 0.22912404, 0.03926966, 0.0485943 , 0.43537305])
